# %%
nums = "mangobanana"

s = nums.index("ano")
s
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 nums = "mangobanana"
# ----> 3 s = nums.index("ano")
#       4 s
#
# ValueError: substring not found
